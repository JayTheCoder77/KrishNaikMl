# %%
# classification problem
# comments are positive or negative
# reviews -> eating , eat ,eaten ; word stem -> eat

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
# porter stemmer
from nltk.stem import PorterStemmer
ps=PorterStemmer()
for word in words:
  print(word+"------>"+ps.stem(word))
# Out:
# eating------>eat
# eats------>eat
# eaten------>eaten
# writing------>write
# writes------>write
# programming------>program
# programs------>program
# history------>histori
# finally------>final
# finalized------>final

# %%
ps.stem('congratulations')
# Out:
# 'congratul'

# %%
ps.stem("sitting")
# Out:
# 'sit'

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("ingeating")
# Out:
# 'ingeat'

# %%
# Snowball stemmer
from nltk.stem import SnowballStemmer
ss = SnowballStemmer('english')
for word in words:
  print(word+"------>"+ss.stem(word))
# Out:
# eating------>eat
# eats------>eat
# eaten------>eaten
# writing------>write
# writes------>write
# programming------>program
# programs------>program
# history------>histori
# finally------>final
# finalized------>final

# %%
print(ps.stem("fairly"),ps.stem("sportingly"))

ss.stem("fairly"),ss.stem("sportingly")
# Out:
# fairli sportingli
# ('fair', 'sport')
